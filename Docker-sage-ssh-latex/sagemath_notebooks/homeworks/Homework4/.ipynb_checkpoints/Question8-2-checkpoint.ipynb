# %%
# Make sure you have autograd installed
import autograd.numpy as np
from autograd import grad, elementwise_grad

# Define the sigmoid function
def sigmoid(w0, w1, w2, x0, x1):
    return 1 / (1 + np.exp(-(w0*x0 + w1*x1 + w2)))

# Define the function to compute the gradient of sigmoid function
def augradf(w0, w1, w2, x0, x1):
    # Define the gradient function using autograd
    grad_sigmoid = elementwise_grad(sigmoid)
    # Evaluate the gradient at the given point
    gradient_value = grad_sigmoid(w0, w1, w2, x0, x1)
    return gradient_value


w0_val = 1.0
w1_val = 2.0
w2_val = 3.0
x0_val = 0.5
x1_val = 0.3

gradient_at_point = augradf(w0=w0_val, w1=w1_val, w2=w2_val, x0=x0_val, x1=x1_val)
print("Gradient of f at the given point:", gradient_at_point)
# Out:
# Gradient of f at the given point: 0.008018363942842556

# %%
from sage.all import *
# Define symbolic variables
w0, w1, w2, x0, x1 = SR.var('w0 w1 w2 x0 x1')

# Define the sigmoid function
sigmoid = 1 / (1 + exp(-(w0*x0 + w1*x1 + w2)))

# Define the gradient of the sigmoid function
angradf = [
    diff(sigmoid, w0),
    diff(sigmoid, w1),
    diff(sigmoid, w2),
    diff(sigmoid, x0),
    diff(sigmoid, x1)
]

# Display the analytical gradient
for i, derivative in enumerate(angradf):
    print(f"∂f/∂{angradf[i].variables()[0]} =", derivative)
# Out:
# ∂f/∂w0 = x0*e^(-w0*x0 - w1*x1 - w2)/(e^(-w0*x0 - w1*x1 - w2) + 1)^2
# ∂f/∂w0 = x1*e^(-w0*x0 - w1*x1 - w2)/(e^(-w0*x0 - w1*x1 - w2) + 1)^2
# ∂f/∂w0 = e^(-w0*x0 - w1*x1 - w2)/(e^(-w0*x0 - w1*x1 - w2) + 1)^2
# ∂f/∂w0 = w0*e^(-w0*x0 - w1*x1 - w2)/(e^(-w0*x0 - w1*x1 - w2) + 1)^2
# ∂f/∂w0 = w1*e^(-w0*x0 - w1*x1 - w2)/(e^(-w0*x0 - w1*x1 - w2) + 1)^2

# %%
# Import necessary libraries
import numpy as np

# Define the range and number of points
num_points = 10
random_points = np.random.rand(num_points, 5)

# Compare results for 10 randomly chosen points
for point in random_points:
    print("Print:", point)
    w0_val=point[0] 
    w1_val=point[1] 
    w2_val=point[2] 
    x0_val=point[3] 
    x1_val = point[4]
    
    # Compute gradients using autograd
    gradient_autograd = augradf(w0=w0_val, w1=w1_val, w2=w2_val, x0=x0_val, x1=x1_val)
    
    # Compute gradients using analytical approach
    gradient_analytical = [float(expr.subs({w0: w0_val, w1: w1_val, w2: w2_val, x0: x0_val, x1: x1_val})) for expr in angradf]
    
    # Print results
    print("Point:", point)
    print("Gradient using augradf:", gradient_autograd)
    print("Gradient using angradf:", gradient_analytical)
    print("\n")
# Out:
# Print: [0.00446152 0.55245114 0.28994354 0.83070482 0.01388596]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_55/3502849052.py in <module>
#      16
#      17     # Compute gradients using autograd
# ---> 18     gradient_autograd = augradf(w0_val, w1_val, w2_val, x0_val, x1_val)
#      19
#      20     # Compute gradients using analytical approach
#
# /tmp/ipykernel_55/2835889020.py in augradf(w0, w1, w2, x0, x1)
#      12     grad_sigmoid = elementwise_grad(sigmoid)
#      13     # Evaluate the gradient at the given point
# ---> 14     gradient_value = grad_sigmoid(w0, w1, w2, x0, x1)
#      15     return gradient_value
#      16
#
# ~/.sage/local/lib/python3.10/site-packages/autograd/wrap_util.py in nary_f(*args, **kwargs)
#      18             else:
#      19                 x = tuple(args[i] for i in argnum)
# ---> 20             return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#      21         return nary_f
#      22     return nary_operator
#
# ~/.sage/local/lib/python3.10/site-packages/autograd/differential_operators.py in elementwise_grad(fun, x)
#      39     of the Jacobian.
#      40     """
# ---> 41     vjp, ans = _make_vjp(fun, x)
#      42     if vspace(ans).iscomplex:
#      43         raise TypeError("Elementwise_grad only applies to real-output functions.")
#
# ~/.sage/local/lib/python3.10/site-packages/autograd/core.py in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# ~/.sage/local/lib/python3.10/site-packages/autograd/tracer.py in trace(start_node, fun, x)
#       8     with trace_stack.new_trace() as t:
#       9         start_box = new_box(x, t, start_node)
# ---> 10         end_box = fun(start_box)
#      11         if isbox(end_box) and end_box._trace == start_box._trace:
#      12             return end_box._value, end_box._node
#
# ~/.sage/local/lib/python3.10/site-packages/autograd/wrap_util.py in unary_f(x)
#      13                 else:
#      14                     subargs = subvals(args, zip(argnum, x))
# ---> 15                 return fun(*subargs, **kwargs)
#      16             if isinstance(argnum, int):
#      17                 x = args[argnum]
#
# /usr/lib/python3/dist-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.__call__ (build/cythonized/sage/symbolic/expression.cpp:61293)()
#    6142             z^2 + x^y
#    6143         """
# -> 6144         return self._parent._call_element_(self, *args, **kwds)
#    6145
#    6146     def variables(self):
#
# /usr/lib/python3/dist-packages/sage/symbolic/ring.pyx in sage.symbolic.ring.SymbolicRing._call_element_ (build/cythonized/sage/symbolic/ring.c:9944)()
#    1047             d = args[0]
#    1048         else:
# -> 1049             raise TypeError("Substitution using function-call syntax "
#    1050                             "and unnamed arguments has been removed. You "
#    1051                             "can use named arguments instead, like "
#
# TypeError: Substitution using function-call syntax and unnamed arguments has been removed. You can use named arguments instead, like EXPR(x=..., y=...)
